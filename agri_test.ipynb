# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("crop_production.csv")
df
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# ...                            ...           ...        ...          ...
# 85729                    Karnataka     DAVANGERE     2001.0  Whole Year
# 85730                    Karnataka     DAVANGERE     2001.0  Whole Year
# 85731                    Karnataka     DAVANGERE     2001.0  Whole Year
# 85732                    Karnataka     DAVANGERE     2001.0  Whole Year
# 85733                    Karnataka           NaN        NaN          NaN
#
#                       Crop     Area  Production
# 0                 Arecanut   1254.0      2000.0
# ...

# %%
df.info

# %%
df.shape

# %%
df.describe()

# %%
fields_are = ['State_name', 'District_name', 'Crop_year', 'Season' , 'Crop', 'Area' , 'Production']
df.dtypes

# %%
df.info()

# %%
df.isnull().any()

# %%
df.isnull().sum()

# %%
print('State_Name : ',df['State_Name'].isnull().sum())
print('District_Name : ',df['District_Name'].isnull().sum())
print('Crop_Year : ',df['Crop_Year'].isnull().sum())
print('Season : ',df['Season'].isnull().sum())
print('Crop : ',df['Crop'].isnull().sum())
print('Area : ',df['Area'].isnull().sum())
print('Production : ',df['Production'].isnull().sum())

# %%
df1 = df['Production'].isnull()
df1

# %%
print(df['State_Name'].unique())
print(df['Season'].unique())
print(df['Crop'].unique())
print(df['Crop_Year'].unique())

# %%
#above_35 = titanic[titanic["Age"] > 35]
#class_23 = titanic[titanic["Pclass"].isin([2, 3])]
#https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html 
df1 = df[df["Production"].isnull()]
df1
# Out:
#                         State_Name    District_Name  Crop_Year       Season  \
# 46     Andaman and Nicobar Islands         NICOBARS     2005.0  Whole Year
# 51     Andaman and Nicobar Islands         NICOBARS     2005.0  Whole Year
# 623                 Andhra Pradesh        ANANTAPUR     2007.0  Kharif
# 630                 Andhra Pradesh        ANANTAPUR     2007.0  Rabi
# 698                 Andhra Pradesh        ANANTAPUR     2009.0  Rabi
# ...                            ...              ...        ...          ...
# 80862                    Karnataka  BENGALURU URBAN     2014.0  Summer
# 82821                    Karnataka   CHAMARAJANAGAR     2007.0  Whole Year
# 82872                    Karnataka   CHAMARAJANAGAR     2008.0  Whole Year
# 82981                    Karnataka   CHAMARAJANAGAR     2010.0  Whole Year
# 85733                    Karnataka              NaN        NaN          NaN
#
#                     Crop     Area  Production
# ...

# %%
#https://sparkbyexamples.com/pandas/pandas-drop-rows-with-condition/#:~:text=Use%20pandas.,rows%20with%20condition(s).
'''
#Using drop() to delete rows based on column value
df.drop(df[df['Fee'] >= 24000].index, inplace = True)

# Remove rows
df2 = df[df.Fee >= 24000]

# If you have space in column name.# Specify column name with in single quotes
df2 = df[df['column name']]

# Using loc
df2 = df.loc[df["Fee"] >= 24000 ]

# Delect rows based on multiple column value
df2 = df[ (df['Fee'] >= 22000) & (df['Discount'] == 2300)]

# Drop rows with None/NaN
df2 = df[df.Discount.notnull()]
'''
df1 = df[df.Crop_Year.notnull() & df.Crop.notnull()]
df1.info() 
df1
df1.drop(df1[df1.Crop_Year.isnull() & df1.Crop.isnull()].index, inplace = True)
df1.info()

# %%
df1 = df[df["Production"].isnull()]
df1

# %%
from google.colab import data_table
#from vega_datasets import data
data_table.enable_dataframe_formatter()
#data_table.DataTable(data.df1(), include_index=False, num_rows_per_page=10)
df1
#from google.colab import data_table
#data_table.disable_dataframe_formatter()
#df1[df1['State_Name']== 'Andaman and Nicobar Islands']
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 46     Andaman and Nicobar Islands      NICOBARS       2005  Whole Year
# 51     Andaman and Nicobar Islands      NICOBARS       2005  Whole Year
# 623                 Andhra Pradesh     ANANTAPUR       2007  Kharif
# 630                 Andhra Pradesh     ANANTAPUR       2007  Rabi
# 698                 Andhra Pradesh     ANANTAPUR       2009  Rabi
# ...                            ...           ...        ...          ...
# 69115                      Haryana         MEWAT       2005  Kharif
# 69116                      Haryana         MEWAT       2005  Kharif
# 69118                      Haryana         MEWAT       2005  Kharif
# 69119                      Haryana         MEWAT       2005  Kharif
# 69123                      Haryana         MEWAT       2005  Rabi
#
#                     Crop     Area  Production
# 46              Arecanut   795.67         NaN
# ...

# %%
from google.colab import data_table
data_table.disable_dataframe_formatter()
data_table.enable_dataframe_formatter()
df[df['State_Name']== 'Andaman and Nicobar Islands']
# Out:
#                       State_Name   District_Name  Crop_Year       Season  \
# 0    Andaman and Nicobar Islands        NICOBARS       2000  Kharif
# 1    Andaman and Nicobar Islands        NICOBARS       2000  Kharif
# 2    Andaman and Nicobar Islands        NICOBARS       2000  Kharif
# 3    Andaman and Nicobar Islands        NICOBARS       2000  Whole Year
# 4    Andaman and Nicobar Islands        NICOBARS       2000  Whole Year
# ..                           ...             ...        ...          ...
# 198  Andaman and Nicobar Islands  SOUTH ANDAMANS       2010  Rabi
# 199  Andaman and Nicobar Islands  SOUTH ANDAMANS       2010  Rabi
# 200  Andaman and Nicobar Islands  SOUTH ANDAMANS       2010  Whole Year
# 201  Andaman and Nicobar Islands  SOUTH ANDAMANS       2010  Whole Year
# 202  Andaman and Nicobar Islands  SOUTH ANDAMANS       2010  Whole Year
#
#                     Crop    Area   Production
# 0               Arecanut  1254.0      2000.00
# ...

# %%
from google.colab import data_table
data_table.disable_dataframe_formatter()
data_table.enable_dataframe_formatter()
df4 = df
#df4 = df4.sort_values(by=['State_Name','Crop'],ascending=False,na_position='first')
df4 = df4.sort_values(by=['State_Name','Crop'],na_position='first')
df4[df4['State_Name']== 'Andaman and Nicobar Islands']
# Out:
#                       State_Name   District_Name  Crop_Year       Season  \
# 0    Andaman and Nicobar Islands        NICOBARS       2000  Kharif
# 10   Andaman and Nicobar Islands        NICOBARS       2001  Kharif
# 19   Andaman and Nicobar Islands        NICOBARS       2002  Whole Year
# 28   Andaman and Nicobar Islands        NICOBARS       2003  Whole Year
# 37   Andaman and Nicobar Islands        NICOBARS       2004  Whole Year
# ..                           ...             ...        ...          ...
# 137  Andaman and Nicobar Islands  SOUTH ANDAMANS       2002  Whole Year
# 147  Andaman and Nicobar Islands  SOUTH ANDAMANS       2003  Whole Year
# 157  Andaman and Nicobar Islands  SOUTH ANDAMANS       2004  Whole Year
# 167  Andaman and Nicobar Islands  SOUTH ANDAMANS       2005  Whole Year
# 180  Andaman and Nicobar Islands  SOUTH ANDAMANS       2006  Whole Year
#
#                Crop     Area  Production
# 0          Arecanut  1254.00     2000.00
# ...

# %%
#df['LoanAmt'].fillna(df['LoanAmt']).mean(), inplace=True)
#https://stackoverflow.com/questions/44111425/cannot-use-fillna-when-a-condition-is-introduced
df2 = df1

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()
df2['Production'].fillna(df2['Production'].mean(), inplace=True)
df2[df2['State_Name']== 'Andaman and Nicobar Islands']
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#                      State_Name District_Name  Crop_Year       Season  \
# 46  Andaman and Nicobar Islands      NICOBARS       2005  Whole Year
# 51  Andaman and Nicobar Islands      NICOBARS       2005  Whole Year
#
#             Crop    Area  Production
# 46      Arecanut  795.67         NaN
# 51  Dry chillies   17.00         NaN

# %%
df3 = df.groupby(['State_Name' , 'District_Name', 'Crop'])['Production'].mean()
df3
# Out:
# State_Name                   District_Name  Crop
# Andaman and Nicobar Islands  NICOBARS       Arecanut         1.508921e+03
#                                             Banana           1.295589e+03
#                                             Black pepper     9.083333e+00
#                                             Cashewnut        1.716037e+02
#                                             Coconut          6.258500e+07
#                                                                  ...
# Gujarat                      AHMADABAD      Small millets    1.500000e+02
#                                             Sugarcane        4.320000e+04
#                                             Tobacco          1.600000e+03
#                                             Urad             6.000000e+02
#                                             Wheat            1.114200e+05
# Name: Production, Length: 4593, dtype: float64

# %%
## df2[df2['Production'] == 'NaN']
## math.isnan is used to check whether a certain variable is NaN or not. 
## We cannot use the regular comparison operator, ==, to check for NaN. 
## NaN is not equal to anything (not even itself!).
# https://www.educative.io/answers/how-to-assign-nan-to-a-variable-in-python
